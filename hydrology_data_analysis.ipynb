# %% [markdown]
# ## Load the Data

# %%
import pandas as pd

# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/BNV4-U11/1H_resampl.csv')

# Display the first few rows of the dataframe
data.head()
# Out:
#                   date        U11   Baseflow  U11_without_baseflow      BNV4
# 0  2016-01-01 00:00:00  15.750000  44.166667              0.000667  0.013916
# 1  2016-01-01 01:00:00  15.583333  39.416667              0.000583  0.155251
# 2  2016-01-01 02:00:00  25.166667  35.250000              0.004583  0.000000
# 3  2016-01-01 03:00:00  18.500000  36.416667              0.002667  0.000000
# 4  2016-01-01 04:00:00  14.250000  37.000000              0.000333  0.000000

# %% [markdown]
# ## Summary Statistics

# %%
# Convert the 'date' column to datetime format
data['date'] = pd.to_datetime(data['date'])

# Check the summary statistics
summary_stats = data.describe()

summary_stats
# Out:
#                       date           U11      Baseflow  U11_without_baseflow  \
# count                26304  26293.000000  26301.000000          26293.000000
# mean   2017-07-01 23:30:00     44.964634    110.451253              0.006616
# min    2016-01-01 00:00:00   -149.000000     35.250000              0.000000
# 25%    2016-09-30 23:45:00     20.666667     88.583333              0.000000
# 50%    2017-07-01 23:30:00     37.666667    117.000000              0.000083
# 75%    2018-04-01 23:15:00     59.833333    136.583333              0.003583
# max    2018-12-31 23:00:00   1178.583333    158.750000              1.085167
# std                    NaN     46.812988     32.976865              0.033060
#
#                BNV4
# count  26278.000000
# mean       0.017830
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       18.820458
# std        0.192913

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt

# Set the date as the index for easier plotting
data.set_index('date', inplace=True)

# Create a figure and a set of subplots
fig, ax = plt.subplots(4, 1, figsize=(15, 20))

# Plot each column
for i, col in enumerate(data.columns):
    data[col].plot(ax=ax[i], title=col)
    ax[i].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

correlation_matrix
# Out:
#                            U11  Baseflow  U11_without_baseflow      BNV4
# U11                   1.000000  0.166338              0.838960  0.488578
# Baseflow              0.166338  1.000000             -0.080670 -0.024300
# U11_without_baseflow  0.838960 -0.080670              1.000000  0.585741
# BNV4                  0.488578 -0.024300              0.585741  1.000000

# %%
#PEARSON CORRELATION HEATMAP
import seaborn as sns
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
