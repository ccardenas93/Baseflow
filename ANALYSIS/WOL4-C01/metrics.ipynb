# %% [markdown]
# ## WOL4 - C01

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL4-C01/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'C01_without_baseflow': 'Qo', 'WOL4': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()

#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('WOL4-C01')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  -1.974
# NSE High flow=  4.764
# Model confidence=  0.119
# Model bias=  0.090
# RMSE=  0.275

# %% [markdown]
# ## MOL5-U17

# %%
# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MOL5-U17/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'U17_without_baseflow': 'Qo', 'MOL5': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()

#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('MOL5-U17')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  -0.271
# NSE High flow=  0.772
# Model confidence=  -0.150
# Model bias=  -0.501
# RMSE=  0.839

# %% [markdown]
# ## WOL5-U05

# %%
# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL5-U05/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'U05_without_baseflow': 'Qo', 'WOL5': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()

#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('WOL5-U05')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  0.303
# NSE High flow=  0.587
# Model confidence=  -0.115
# Model bias=  -0.695
# RMSE=  0.919

# %% [markdown]
# ## MAL1-C11

# %%
# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MAL1-C11/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'C11_without_baseflow': 'Qo', 'MAL1': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()

#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('MAL1-C11')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  -16.553
# NSE High flow=  32.927
# Model confidence=  4.263
# Model bias=  1.750
# RMSE=  0.302

# %% [markdown]
# ## BNV8-U19

# %%
# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV8-U19/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'U19_without_baseflow': 'Qo', 'BNV8': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()

#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('BNV8-U19')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  -13.029
# NSE High flow=  4.055
# Model confidence=  -0.178
# Model bias=  -0.570
# RMSE=  2.895

# %% [markdown]
# ## BNV4-U11

# %%
# Load the data
data = pd.read_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV4-U11/1H_resampl.csv')
# First, let's rename the columns for easier understanding and calculation
data = data.rename(columns={'U11_without_baseflow': 'Qo', 'BNV4': 'Qs'})

# Calculating Model Bias
model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()

# Calculating Model Confidence
Qo_mean = data['Qo'].mean()
model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency
nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()

# Calculating Nash-Sutcliffe Efficiency High Flow
nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()
#calculate the RMSE
rmse1 = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))
print('NSE1=  %.3f' % nash_sutcliffe_efficiency)
print('NSE High flow=  %.3f' % nash_sutcliffe_efficiency_high_flow)
print('Model confidence=  %.3f' % model_confidence)
print('Model bias=  %.3f' % model_bias)
print('RMSE=  %.3f' % rmse1)
#model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse1

#make a cumulative plot of the data
data['Qo_cum'] = data['Qo'].cumsum()
data['Qs_cum'] = data['Qs'].cumsum()

# Initialize the plot
fig, ax = plt.subplots(figsize=(15, 5))

# Plotting Qo_cum
ax.plot(data['Qo_cum'], label='Qo_cum')

# Plotting Qs_cum
ax.plot(data['Qs_cum'], label='Qs_cum')

# Adding details and formatting to the plot
ax.set_xlabel('Date')
ax.set_ylabel('Discharge (m3/s)')
ax.set_title('BNV4-U11')
ax.legend(loc='upper right')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# NSE1=  -27.312
# NSE High flow=  37.478
# Model confidence=  10.254
# Model bias=  1.693
# RMSE=  0.176

# %%
import pandas as pd
import numpy as np
import os

def calculate_metrics(file_path, col_Qo, col_Qs):
    data = pd.read_csv(file_path)
    data = data.rename(columns={col_Qo: 'Qo', col_Qs: 'Qs'})
    Qo_mean = data['Qo'].mean()

    model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()
    model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency_high_flow = 1- (((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum())
    rmse = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))

    return model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse

file_paths = ['C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL4-C01/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MOL5-U17/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL5-U05/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MAL1-C11/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV8-U19/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV4-U11/1H_resampl.csv']

col_Qos = ['C01_without_baseflow', 'U17_without_baseflow', 'U05_without_baseflow', 'C11_without_baseflow', 'U19_without_baseflow', 'U11_without_baseflow']
col_Qss = ['WOL4', 'MOL5', 'WOL5', 'MAL1', 'BNV8', 'BNV4']

results = []

for file_path, col_Qo, col_Qs in zip(file_paths, col_Qos, col_Qss):
    model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse = calculate_metrics(file_path, col_Qo, col_Qs)
    # Extract the file name from the file path
    file_name = os.path.basename(file_path)
    # Keep only the first 8 characters of the file name
    file_name = file_name[:8]
    results.append([file_name, model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse])

results_df = pd.DataFrame(results, columns=['File', 'Model Bias', 'Model Confidence', 'Nash-Sutcliffe Efficiency', 'Nash-Sutcliffe Efficiency High Flow', 'RMSE'])
results_df.head()
# Out:
#        File  Model Bias  Model Confidence  Nash-Sutcliffe Efficiency  \
# 0  1H_resam    0.089794          0.119267                  -1.974238
# 1  1H_resam   -0.500901         -0.150478                  -0.271216
# 2  1H_resam   -0.695483         -0.114677                   0.303139
# 3  1H_resam    1.749786          4.263201                 -16.552745
# 4  1H_resam   -0.570246         -0.177608                 -13.028625
#
#    Nash-Sutcliffe Efficiency High Flow      RMSE
# 0                            -3.764449  0.274675
# 1                             0.228041  0.838745
# 2                             0.412830  0.918617
# 3                           -31.927301  0.301653
# 4                            -3.054527  2.895484

# %%
##########For 1 hour timestep##########

import pandas as pd
import numpy as np
import os

def calculate_metrics(file_path, col_Qo, col_Qs):
    data = pd.read_csv(file_path)
    data = data.rename(columns={col_Qo: 'Qo', col_Qs: 'Qs'})
    data = data.dropna()
    # #dop 0 values
    # data = data[data['Qs'] != 0]
    # print(data.info())
    Qo_mean = data['Qo'].mean()

    model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()
    model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency_high_flow = 1-(((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum())
    rmse = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))

    return model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse

file_paths = ['C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL4-C01/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MOL5-U17/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/WOL5-U05/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/MAL1-C11/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV8-U19/1H_resampl.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/BNV4-U11/1H_resampl.csv']

col_Qos = ['C01_without_baseflow', 'U17_without_baseflow', 'U05_without_baseflow', 'C11_without_baseflow', 'U19_without_baseflow', 'U11_without_baseflow']
col_Qss = ['WOL4', 'MOL5', 'WOL5', 'MAL1', 'BNV8', 'BNV4']

results = []

for file_path, col_Qo, col_Qs in zip(file_paths, col_Qos, col_Qss):
    model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse = calculate_metrics(file_path, col_Qo, col_Qs)
    
    # Extract the specific part of the path
    name = file_path.split('/')[-2]
    results.append([name, model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse])

results_df = pd.DataFrame(results, columns=['Basin', 'Model Bias', 'Model Confidence', 'NSE', 'NSE High Flow', 'RMSE'])
print(results_df)
results_df.to_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/Result_hourly.csv', index=False)
# Out:
#       Basin  Model Bias  Model Confidence        NSE  NSE High Flow      RMSE
# 0  WOL4-C01    0.089853          0.118982  -1.974367      -3.764489  0.274811
# 1  MOL5-U17   -0.501326         -0.149952  -0.271223       0.228039  0.840007
# 2  WOL5-U05   -0.695713         -0.114451   0.303118       0.412821  0.919964
# 3  MAL1-C11    1.749786          4.231694 -16.552745     -31.927301  0.303202
# 4  BNV8-U19   -0.570246         -0.176558 -13.028625      -3.054527  2.900590
# 5  BNV4-U11    1.693616         10.250910 -27.312294     -36.478477  0.175981

# %%
########for 5 mins 
import pandas as pd
import numpy as np
import os

def calculate_metrics(file_path, col_Qo, col_Qs):
    data = pd.read_csv(file_path)
    data = data.rename(columns={col_Qo: 'Qo', col_Qs: 'Qs'})
    # data = data.dropna()
    # #dop 0 values
    # data = data[data['Qs'] != 0]
    # print(data.info())
    Qo_mean = data['Qo'].mean()

    model_bias = (data['Qs'] - data['Qo']).sum() / data['Qo'].sum()
    model_confidence = (data['Qs'] - Qo_mean).sum() / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency = (((data['Qo'] - Qo_mean)**2).sum() - ((data['Qo'] - data['Qs'])**2).sum()) / ((data['Qo'] - Qo_mean)**2).sum()
    nash_sutcliffe_efficiency_high_flow = ((data['Qo'] + Qo_mean) * (data['Qs'] - data['Qo'])**2).sum() / ((data['Qo'] + Qo_mean) * (data['Qo'] - Qo_mean)**2).sum()
    rmse = np.sqrt(((data['Qs'] - data['Qo'])**2).sum() / len(data))

    return model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse

file_paths = ['C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/WOL4-C01/output.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/MOL5-U17/output.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/WOL5-U05/output.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/MAL1-C11/output.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/BNV8-U19/output.csv',
              'C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/BNV4-U11/output.csv']

col_Qos = ['C01_without_baseflow', 'U17_without_baseflow', 'U05_without_baseflow', 'C11_without_baseflow', 'U19_without_baseflow', 'U11_without_baseflow']
col_Qss = ['WOL4', 'MOL5', 'WOL5', 'MAL1', 'BNV8', 'BNV4']

results = []

for file_path, col_Qo, col_Qs in zip(file_paths, col_Qos, col_Qss):
    model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse = calculate_metrics(file_path, col_Qo, col_Qs)
    
    # Extract the specific part of the path
    name = file_path.split('/')[-2]
    results.append([name, model_bias, model_confidence, nash_sutcliffe_efficiency, nash_sutcliffe_efficiency_high_flow, rmse])

results_df = pd.DataFrame(results, columns=['Basin', 'Model Bias', 'Model Confidence', 'NSE', 'NSE High Flow', 'RMSE'])
print(results_df)
results_df.to_csv('C:/Users/carsk/OneDrive - KU Leuven/Thesis/Revised_RESULTS/Baseflow/ANALYSIS/Results_5Mins.csv', index=False)
# Out:
#       Basin  Model Bias  Model Confidence        NSE  NSE High Flow      RMSE
# 0  WOL4-C01    0.090133          0.095670  -4.577294       6.959666  0.419328
# 1  MOL5-U17   -0.501130         -0.131180  -1.189661       1.156920  1.175415
# 2  WOL5-U05   -0.695453         -0.100971   0.076934       0.836591  1.122668
# 3  MAL1-C11    1.750248          3.191933 -27.132752      44.721327  0.440125
# 4  BNV8-U19   -0.570247         -0.161473 -30.633294       9.959315  4.548199
# 5  BNV4-U11    1.691568          7.290217 -47.801039      73.470766  0.272822
